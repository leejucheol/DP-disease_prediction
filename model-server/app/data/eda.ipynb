# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./protein_disease.csv')
df = df.drop(columns=['Disease Name', 'sequence'])
df.shape
# Out:
# (12619, 2)

# %%
# 중복 행 제거
df_no_duplicates = df.drop_duplicates()

# 중복 제거 전후 행 수 비교
print(f"Original DataFrame shape: {df.shape}")
print(f"DataFrame shape after removing duplicates: {df_no_duplicates.shape}")

# 원본 데이터프레임 업데이트
df = df_no_duplicates
# Out:
# Original DataFrame shape: (12619, 2)
# DataFrame shape after removing duplicates: (12619, 2)
